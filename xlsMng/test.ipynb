# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_excel('media/op.xlsx')

# %%
df
# Out:
#      Unnamed: 0         m/z  Retention time (min) Accepted Compound ID  \
# 0             0  622.443865              6.435400         001_C24:0 PC
# 1             1  468.308355              4.331133         001_C24:0 PD
# 2             2  494.323962              4.469333    003_C16:1 LPC IST
# 3             3  496.339484              4.803700        004_C16:0 LPC
# 4             4  520.339703              4.643200    005_C18:2_IST_LPC
# ..          ...         ...                   ...                  ...
# 167         167  946.784330             11.593550                  NaN
# 168         168  948.800491             11.829850                  NaN
# 169         169 -950.814096             11.959133                  NaN
# 170         170  952.831543             12.199883                  NaN
# 171         171 -968.766727             11.339433                  NaN
#
#      2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# ...

# %%
t = df['Retention Time Roundoff'].unique()

# %%
t
# Out:
# array([  6,   4,   5,   8,   9,  10,   7,  12,  13,  11, -11, -13])

# %%
l = { t[i]:0 for i in range(len(t))}

# %%
l
# Out:
# {6: 0,
#  4: 0,
#  5: 0,
#  8: 0,
#  9: 0,
#  10: 0,
#  7: 0,
#  12: 0,
#  13: 0,
#  11: 0,
#  -11: 0,
#  -13: 0}

# %%
count = df['Retention Time Roundoff'].value_counts()

# %%
count
# Out:
#  9     51
#  12    33
#  11    25
#  8     25
#  5     15
#  10     9
#  13     5
#  7      3
#  6      2
#  4      2
# -13     1
# -11     1
# Name: Retention Time Roundoff, dtype: int64

# %%
for i in range(df.shape[0]):
    l[df['Retention Time Roundoff'][i]] = l[df['Retention Time Roundoff'][i]] + df['m/z'][i]

# %%
df.shape
# Out:
# (172, 1051)

# %%
l
# Out:
# {6: 998.7858223000001,
#  4: 962.6323165,
#  5: 7506.8255402,
#  8: 18470.6719394,
#  9: 37557.28127369999,
#  10: 6350.683769599999,
#  7: 2047.4805824,
#  12: 25086.634564400003,
#  13: 4324.0587052,
#  11: 19082.4877235,
#  -11: nan,
#  -13: 932.8633341}

# %%
df[df['Retention Time Roundoff']==-11]
# Out:
#      Unnamed: 0  m/z  Retention time (min) Accepted Compound ID  \
# 129         129  NaN            -10.768783                 hijk
#
#      2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 129                16312.02943                132655.9544
#
#      2789_WHI_BAA_LIP_331530-51  2790_WHI_BAA_LIP_422284-42  \
# 129                 117717.9244                 94710.32681
#
#      2791_WHI_BAA_LIP_330045-45  2792_WHI_BAA_LIP_406434-39  ...  \
# 129                 330617.4421                 818130.3539  ...
#
#      3734reinja_WHI_BAA_LIP_420751-38  3735_WHI_BAA_LIP_202764-45  \
# 129                       66084.16902                 12857.82652
#
#      3736_WHI_BAA_LIP_236674-35  3737_WHI_BAA_LIP_468528-53  \
# 129                 64274.10834                 147841.4389
#
#      3738_WHI_BAA_LIP_367142-76  3739_WHI_BAA_LIP_364303-45  \
# 129                 206073.2668                 21041.54407
#
#      3740_WHI_BAA_LIP_434772-33  3740a_WHI_BAA_LIP_PrefB192  \
# ...

# %%
l
# Out:
# {6: 998.7858223000001,
#  4: 962.6323165,
#  5: 7506.8255402,
#  8: 18470.6719394,
#  9: 37557.28127369999,
#  10: 6350.683769599999,
#  7: 2047.4805824,
#  12: 25086.634564400003,
#  13: 4324.0587052,
#  11: 19082.4877235,
#  -11: nan,
#  -13: 932.8633341}

# %%
count
# Out:
#  9     51
#  12    33
#  11    25
#  8     25
#  5     15
#  10     9
#  13     5
#  7      3
#  6      2
#  4      2
# -13     1
# -11     1
# Name: Retention Time Roundoff, dtype: int64

# %%
len(count)
# Out:
# 12

# %%
for i in l.keys():
    l[i] = l[i]/count[i]

# %%
l
# Out:
# {6: 499.39291115000003,
#  4: 481.31615825,
#  5: 500.45503601333337,
#  8: 738.826877576,
#  9: 736.4172798764704,
#  10: 705.6315299555555,
#  7: 682.4935274666667,
#  12: 760.2010474060608,
#  13: 864.81174104,
#  11: 763.2995089399999,
#  -11: nan,
#  -13: 932.8633341}

# %%
df.head()
# Out:
#    Unnamed: 0         m/z  Retention time (min) Accepted Compound ID  \
# 0           0  622.443865              6.435400         001_C24:0 PC
# 1           1  468.308355              4.331133         001_C24:0 PD
# 2           2  494.323962              4.469333    003_C16:1 LPC IST
# 3           3  496.339484              4.803700        004_C16:0 LPC
# 4           4  520.339703              4.643200    005_C18:2_IST_LPC
#
#    2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 0               3.391827e+06               3.350603e+06
# 1               9.943031e+05               5.452427e+05
# 2               2.983384e+06               1.608636e+06
# 3               8.898708e+07               3.733250e+07
# 4               1.687672e+07               1.148176e+07
#
#    2789_WHI_BAA_LIP_331530-51  2790_WHI_BAA_LIP_422284-42  \
# 0                3.321951e+06                3.434692e+06
# 1                6.704707e+05                5.744235e+05
# ...

# %%
df.shape
# Out:
# (172, 1051)

# %%
df = df.drop(['Unnamed: 0','m/z','Accepted Compound ID', 'Retention time (min)'],axis=1)

# %%
df.head()
# Out:
#    2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 0               3.391827e+06               3.350603e+06
# 1               9.943031e+05               5.452427e+05
# 2               2.983384e+06               1.608636e+06
# 3               8.898708e+07               3.733250e+07
# 4               1.687672e+07               1.148176e+07
#
#    2789_WHI_BAA_LIP_331530-51  2790_WHI_BAA_LIP_422284-42  \
# 0                3.321951e+06                3.434692e+06
# 1                6.704707e+05                5.744235e+05
# 2                1.820152e+06                1.857638e+06
# 3                4.367946e+07                3.549519e+07
# 4                1.339046e+07                9.036667e+06
#
#    2791_WHI_BAA_LIP_330045-45  2792_WHI_BAA_LIP_406434-39  \
# 0                3.256514e+06                3.396340e+06
# 1                5.051156e+05                6.699923e+05
# 2                1.042530e+06                1.748126e+06
# ...

# %%
df_2 =[ l[df['Retention Time Roundoff'][i]] for i in range(df.shape[0])]

# %%
type(df_2)
# Out:
# list

# %%
df["Mean m/z"] = df_2

# %%
df.head()
# Out:
#    2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 0               3.391827e+06               3.350603e+06
# 1               9.943031e+05               5.452427e+05
# 2               2.983384e+06               1.608636e+06
# 3               8.898708e+07               3.733250e+07
# 4               1.687672e+07               1.148176e+07
#
#    2789_WHI_BAA_LIP_331530-51  2790_WHI_BAA_LIP_422284-42  \
# 0                3.321951e+06                3.434692e+06
# 1                6.704707e+05                5.744235e+05
# 2                1.820152e+06                1.857638e+06
# 3                4.367946e+07                3.549519e+07
# 4                1.339046e+07                9.036667e+06
#
#    2791_WHI_BAA_LIP_330045-45  2792_WHI_BAA_LIP_406434-39  \
# 0                3.256514e+06                3.396340e+06
# 1                5.051156e+05                6.699923e+05
# 2                1.042530e+06                1.748126e+06
# ...

# %%
df["Mean m/z"].iloc[2]
# Out:
# 481.31615825

# %%
df_t = pd.read_excel('media/op2.xlsx')

# %%
df_t.head()
# Out:
#    2788e_WHI_BAA_LIP_PrefB01  2788f_WHI_BAA_LIP_PrefA01  \
# 0               3.391827e+06               3.350603e+06
# 1               9.943031e+05               5.452427e+05
# 2               2.983384e+06               1.608636e+06
# 3               8.898708e+07               3.733250e+07
# 4               1.687672e+07               1.148176e+07
#
#    2789_WHI_BAA_LIP_331530-51  2790_WHI_BAA_LIP_422284-42  \
# 0                3.321951e+06                3.434692e+06
# 1                6.704707e+05                5.744235e+05
# 2                1.820152e+06                1.857638e+06
# 3                4.367946e+07                3.549519e+07
# 4                1.339046e+07                9.036667e+06
#
#    2791_WHI_BAA_LIP_330045-45  2792_WHI_BAA_LIP_406434-39  \
# 0                3.256514e+06                3.396340e+06
# 1                5.051156e+05                6.699923e+05
# 2                1.042530e+06                1.748126e+06
# ...
